# %%
"""
preprocess images and create new image folder 
"""
# Out:
# '\npreprocess images and create new image folder \n'

# %%
import image_preprocess as pp 
import os
from multiprocessing import Pool
from tqdm import tqdm

# %%
source_path = "Data/images/"
resize_to_size = (650,650)
destination_path = "Data/images_650_V2/"

# %%
jobs = [(img_file,source_path,destination_path,resize_to_size) for img_file in os.listdir(source_path)]

# %%
list(tqdm(Pool().imap_unordered(pp.preprocess_image, jobs), total=len(jobs)))
# Out:
# 100%|██████████| 35126/35126 [40:01<00:00, 14.63it/s]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
#Preprocessed
